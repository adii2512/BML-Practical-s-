# %% [markdown]
# <a href="https://colab.research.google.com/github/adii2512/BML-Practical-s-/blob/main/Experiment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
from google.colab import files

# %%
uploaded = files.upload()
data = pd.read_csv("Salary_dataset.csv")

# %%
print("----- Head of Dataset -----")
print(data.head())

# %%
print("\n----- Dataset Info -----")
print(data.info())

# %%
print("\n----- Missing Values -----")
print(data.isnull().sum())

# %%
print("\n----- Duplicate Rows -----")
print(data.duplicated().sum())

# %%
if "Unnamed: 0" in data.columns:
    data = data.drop(columns=["Unnamed: 0"])

# %%
plt.figure(figsize=(12,5))

# %%
plt.subplot(1,2,1)
sns.scatterplot(x="YearsExperience", y="Salary", data=data)
plt.title("YearsExperience vs Salary")

# %%
plt.subplot(1,2,2)
sns.histplot(data["Salary"], bins=10, kde=True)
plt.title("Salary Distribution")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
